# %% [markdown]
# # BUSINESS QUESTIONS

# %% [markdown]
# 1. What is the number of properties per year of construction?
#
# 2. What is the smallest number of rooms per building construction number?
#
# 3. What is the highest purchase price for each room number?
#
# 4. What is the sum of all purchase prices by number of rooms?
#
# 5. What is the sum of all purchase prices by number of bedrooms and bathrooms?
#
# 6. What is the average room size of the buildings per year of construction?
#
# 7. What is the median room size of the buildings per year of construction?
#
# 8. What is the standard deviation of the room size of the property per year of construction?
#
# 9. How is the average growth in the purchase price of real estate, per year, per day and per week of the year
#
# 10. Look at the map and be able to identify the houses with the highest price
#
#
# 11. Create a new column called 'dormitory_type'
#
#     * if the value of the column 'berdrooms' is equal to 1 -> studio
#     * if the value of the column 'berdrooms' is equal to 2 -> apartment
#     * if the value of the column 'berdrooms' > 2 -> house
#
#
# 12. Make a bar graph that represents the sum of the prices by the number of rooms
#
# 13. Draw a line graph that represents the average prices for the year of construction of the properties.
#
# 14. Make a bar graph that represents the average price by type of dorms.
#
# 15. Draw a line graph showing the evolution of the average prices for the year of renovation of the buildings, from the year 1930
#
# 16. Make a table showing the average prices by year of construction and type of bedroom for the properties
#
# 17. Create a Dashboard with the graphs of questions 12,13,14 (1 row and 2 columns)
#
# 18. Create a Dashboard with the graphs of questions 12 and 14 (2 columns)

# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

from IPython.core.display  import HTML
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ## Helper Function

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set()
    
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # LOADING DATA

# %%
data = pd.read_csv('../data/raw/data_raw.csv')

# %% [markdown]
# # ANSWERING BUSINESS QUESTIONS

# %% [markdown]
# ## What is the number of properties per year of construction?

# %%
data[['id', 'yr_built']].groupby('yr_built').count().reset_index().rename(columns={'id':'num_houses'}).sort_values('num_houses', ascending=False).head()
# Out:
#      yr_built  num_houses
# 114      2014         559
# 106      2006         454
# 105      2005         450
# 104      2004         433
# 103      2003         422

# %% [markdown]
# ## What is the smallest number of rooms per building construction number?

# %%
data[['bedrooms', 'yr_built']].groupby('yr_built').min().reset_index().rename(columns={'bedrooms':'num_bedrooms'}).sort_values('num_bedrooms', ascending=False)
# Out:
#      yr_built  num_bedrooms
# 94       1994             2
# 95       1995             2
# 93       1993             2
# 92       1992             2
# 51       1951             2
# 87       1987             2
# 86       1986             2
# 84       1984             2
# 69       1969             2
# 32       1932             2
# 33       1933             2
# 34       1934             2
# 81       1981             2
# 80       1980             2
# 70       1970             2
# 38       1938             2
# 71       1971             2
# 72       1972             2
# 73       1973             2
# 74       1974             2
# 75       1975             2
# 97       1997             2
# 98       1998             2
# 2        1902             2
# 59       1959             2
# 4        1904             2
# 113      2013             2
# 112      2012             2
# 1        1901             2
# 110      2010             2
# 9        1909             2
# 57       1957             2
# 56       1956             2
# 55       1955             2
# 105      2005             2
# 104      2004             2
# 102      2002             2
# 64       1964             2
# 65       1965             2
# 68       1968             1
# 67       1967             1
# 66       1966             1
# 0        1900             1
# 83       1983             1
# 76       1976             1
# 100      2000             1
# 114      2014             1
# 111      2011             1
# 109      2009             1
# 108      2008             1
# 107      2007             1
# 101      2001             1
# 91       1991             1
# 77       1977             1
# 89       1989             1
# 88       1988             1
# 61       1961             1
# 82       1982             1
# 79       1979             1
# 78       1978             1
# 62       1962             1
# 58       1958             1
# 60       1960             1
# 16       1916             1
# 26       1926             1
# 24       1924             1
# 23       1923             1
# 22       1922             1
# 21       1921             1
# 20       1920             1
# 19       1919             1
# 18       1918             1
# 17       1917             1
# 15       1915             1
# 28       1928             1
# 14       1914             1
# 12       1912             1
# 11       1911             1
# 10       1910             1
# 8        1908             1
# 7        1907             1
# 6        1906             1
# 5        1905             1
# 3        1903             1
# 27       1927             1
# 25       1925             1
# 43       1943             1
# 42       1942             1
# 54       1954             1
# 52       1952             1
# 50       1950             1
# 49       1949             1
# 48       1948             1
# 47       1947             1
# 46       1946             1
# 45       1945             1
# 44       1944             1
# 29       1929             1
# 115      2015             1
# 37       1937             1
# 31       1931             1
# 40       1940             1
# 30       1930             1
# 39       1939             1
# 41       1941             1
# 36       1936             1
# 35       1935             1
# 53       1953             0
# 63       1963             0
# 90       1990             0
# 99       1999             0
# 106      2006             0
# 13       1913             0
# 103      2003             0
# 96       1996             0
# 85       1985             0

# %% [markdown]
# ## What is the highest purchase price for each room number?

# %%
data[['price', 'bedrooms']].groupby('bedrooms').max().reset_index()
# Out:
#     bedrooms      price
# 0          0 1295650.00
# 1          1 1247000.00
# 2          2 3278000.00
# 3          3 3800000.00
# 4          4 4489000.00
# 5          5 7062500.00
# 6          6 7700000.00
# 7          7 3200000.00
# 8          8 3300000.00
# 9          9 1400000.00
# 10        10 1148000.00
# 11        11  520000.00
# 12        33  640000.00

# %% [markdown]
# ## What is the sum of all purchase prices by number of rooms?

# %%
data[['price', 'bedrooms']].groupby('bedrooms').sum().reset_index()
# Out:
#     bedrooms         price
# 0          0    5323550.00
# 1          1   63210934.00
# 2          2 1107788602.00
# 3          3 4580263939.00
# 4          4 4372957028.00
# 5          5 1259346326.00
# 6          6  224541613.00
# 7          7   36145017.00
# 8          8   14366000.00
# 9          9    5363999.00
# 10        10    2458000.00
# 11        11     520000.00
# 12        33     640000.00

# %% [markdown]
# ## What is the sum of all purchase prices by number of bedrooms and bathrooms?

# %%
data[['price', 'bedrooms', 'bathrooms']].groupby(['bedrooms', 'bathrooms']).sum()
# Out:
#                            price
# bedrooms bathrooms
# 0        0.00         3642600.00
#          0.75          265000.00
#          1.00          228000.00
#          1.50          288000.00
#          2.50          899950.00
# 1        0.00          839000.00
#          0.50          255000.00
#          0.75         6778450.00
#          1.00        43694934.00
#          1.25         1763500.00
#          1.50         3908950.00
#          1.75         1464200.00
#          2.00         1783000.00
#          2.25         1744900.00
#          2.50          979000.00
# 2        0.50          382000.00
#          0.75         8515351.00
#          1.00       542297424.00
#          1.25         1406950.00
#          1.50       120575703.00
#          1.75       143259595.00
#          2.00        96844945.00
#          2.25        61083264.00
#          2.50       106556678.00
#          2.75        11018842.00
#          3.00         8379650.00
#          3.25         6933200.00
#          3.50          535000.00
# 3        0.75         4984201.00
#          1.00       598408675.00
#          1.25         2420500.00
#          1.50       330098904.00
#          1.75       814396658.00
#          2.00       468949131.00
#          2.25       525264833.00
#          2.50      1219588146.00
#          2.75       177977194.00
#          3.00       137225819.00
#          3.25       140625098.00
#          3.50       113443030.00
#          3.75        15422600.00
#          4.00        12668000.00
#          4.25        10106150.00
#          4.50         8685000.00
# 4        0.50          312500.00
#          0.75          662500.00
#          1.00       127128723.00
#          1.50       112362964.00
#          1.75       352314065.00
#          2.00       249462431.00
#          2.25       415407291.00
#          2.50      1455709408.00
#          2.75       420887477.00
#          3.00       234059206.00
#          3.25       281538935.00
#          3.50       393349682.00
#          3.75       101730616.00
#          4.00        77074010.00
#          4.25        60567790.00
#          4.50        44919910.00
#          4.75        11197990.00
#          5.00        12441530.00
#          5.25         8115000.00
#          5.50        11775000.00
#          5.75         1940000.00
# 5        1.00        21209082.00
#          1.50        21803990.00
#          1.75        65804785.00
#          2.00        54954450.00
#          2.25        76428068.00
#          2.50       175781842.00
#          2.75       141885906.00
#          3.00       118241055.00
#          3.25       131455548.00
#          3.50       151988257.00
#          3.75        55468550.00
#          4.00        62900750.00
#          4.25        34223240.00
#          4.50        52449213.00
#          4.75        24147100.00
#          5.00        15438800.00
#          5.25        12141800.00
#          5.50        12208000.00
#          5.75         7490000.00
#          6.00        10231000.00
#          6.25         6188000.00
#          6.50         2238890.00
#          6.75         4668000.00
# 6        1.00         3545000.00
#          1.50         1956400.00
#          1.75         8644000.00
#          2.00        11083200.00
#          2.25        10599000.00
#          2.50        17255170.00
#          2.75        25873550.00
#          3.00        28113940.00
#          3.25        10128350.00
#          3.50        14947160.00
#          3.75        10475694.00
#          4.00        10715750.00
#          4.25        12365000.00
#          4.50        20822899.00
#          4.75         7960000.00
#          5.00         6773000.00
#          5.25         2218500.00
#          6.00         5300000.00
#          6.50         1180000.00
#          7.75         6885000.00
#          8.00         7700000.00
# 7        1.00          291000.00
#          1.50          885000.00
#          2.25         1909000.00
#          2.50          879000.00
#          2.75         2060000.00
#          3.00         3655000.00
#          3.25          419000.00
#          3.50         5010000.00
#          3.75         1663160.00
#          4.00         3449957.00
#          4.25         3274000.00
#          4.50         4605000.00
#          4.75         3184900.00
#          5.50         1240000.00
#          5.75          540000.00
#          6.75          800000.00
#          8.00         2280000.00
# 8        2.50          700000.00
#          2.75         2670000.00
#          3.00          948000.00
#          3.25          430000.00
#          3.50         1970000.00
#          3.75          808000.00
#          4.00         4200000.00
#          5.00          490000.00
#          6.00         2150000.00
# 9        3.00         1634000.00
#          4.00         1400000.00
#          4.50         1879999.00
#          7.50          450000.00
# 10       2.00          650000.00
#          3.00          660000.00
#          5.25         1148000.00
# 11       3.00          520000.00
# 33       1.75          640000.00

# %% [markdown]
# ## What is the average room size of the buildings per year of construction?

# %%
data[['sqft_living', 'yr_built']].groupby('yr_built').mean()
# Out:
#           sqft_living
# yr_built
# 1900          1732.01
# 1901          1763.62
# 1902          1919.63
# 1903          1507.74
# 1904          1603.18
# 1905          1965.81
# 1906          1802.23
# 1907          1904.28
# 1908          1699.64
# 1909          1900.11
# 1910          1880.72
# 1911          1893.84
# 1912          1829.05
# 1913          1902.27
# 1914          1850.93
# 1915          1726.09
# 1916          1758.99
# 1917          1668.18
# 1918          1539.77
# 1919          1677.95
# 1920          1564.18
# 1921          1841.80
# 1922          1723.06
# 1923          1670.12
# 1924          1639.93
# 1925          1840.10
# 1926          1787.58
# 1927          1824.96
# 1928          1765.00
# 1929          1817.11
# 1930          1812.33
# 1931          1949.02
# 1932          1587.63
# 1933          2193.00
# 1934          1786.67
# 1935          1813.75
# 1936          1850.90
# 1937          1937.59
# 1938          1764.42
# 1939          1704.34
# 1940          1777.35
# 1941          1574.16
# 1942          1306.56
# 1943          1245.77
# 1944          1371.21
# 1945          1442.74
# 1946          1660.29
# 1947          1559.31
# 1948          1607.50
# 1949          1537.62
# 1950          1633.11
# 1951          1693.12
# 1952          1732.99
# 1953          1705.79
# 1954          1660.50
# 1955          1702.81
# 1956          1784.94
# 1957          1898.51
# 1958          1915.42
# 1959          1815.05
# 1960          1888.28
# 1961          1847.64
# 1962          1923.25
# 1963          1988.75
# 1964          2101.58
# 1965          2149.50
# 1966          1950.88
# 1967          1908.62
# 1968          1901.16
# 1969          1788.44
# 1970          1940.83
# 1971          1832.31
# 1972          2018.19
# 1973          2167.68
# 1974          2075.36
# 1975          2086.05
# 1976          2189.40
# 1977          2159.65
# 1978          2215.71
# 1979          2246.70
# 1980          2103.30
# 1981          1941.12
# 1982          2118.63
# 1983          2049.59
# 1984          2218.31
# 1985          2113.06
# 1986          2139.04
# 1987          2223.68
# 1988          2408.86
# 1989          2442.48
# 1990          2517.92
# 1991          2622.95
# 1992          2402.16
# 1993          2430.04
# 1994          2249.80
# 1995          2410.28
# 1996          2585.14
# 1997          2513.99
# 1998          2594.16
# 1999          2573.64
# 2000          2646.31
# 2001          2880.71
# 2002          2600.15
# 2003          2458.55
# 2004          2537.37
# 2005          2403.05
# 2006          2531.80
# 2007          2320.65
# 2008          2246.04
# 2009          1977.52
# 2010          2225.80
# 2011          2313.68
# 2012          2378.74
# 2013          2636.59
# 2014          2615.39
# 2015          2596.32

# %% [markdown]
# ## What is the median room size of the buildings per year of construction?

# %%
data[['sqft_living', 'yr_built']].groupby('yr_built').median()
# Out:
#           sqft_living
# yr_built
# 1900          1540.00
# 1901          1610.00
# 1902          1600.00
# 1903          1505.00
# 1904          1280.00
# 1905          1865.00
# 1906          1600.00
# 1907          1700.00
# 1908          1575.00
# 1909          1705.00
# 1910          1580.00
# 1911          1930.00
# 1912          1670.00
# 1913          1810.00
# 1914          1725.00
# 1915          1650.00
# 1916          1490.00
# 1917          1435.00
# 1918          1370.00
# 1919          1545.00
# 1920          1545.00
# 1921          1695.00
# 1922          1590.00
# 1923          1535.00
# 1924          1450.00
# 1925          1640.00
# 1926          1715.00
# 1927          1620.00
# 1928          1610.00
# 1929          1760.00
# 1930          1690.00
# 1931          1850.00
# 1932          1460.00
# 1933          1635.00
# 1934          1460.00
# 1935          1420.00
# 1936          1680.00
# 1937          1805.00
# 1938          1505.00
# 1939          1525.00
# 1940          1590.00
# 1941          1390.00
# 1942          1160.00
# 1943          1130.00
# 1944          1290.00
# 1945          1370.00
# 1946          1570.00
# 1947          1410.00
# 1948          1440.00
# 1949          1370.00
# 1950          1450.00
# 1951          1520.00
# 1952          1605.00
# 1953          1520.00
# 1954          1550.00
# 1955          1560.00
# 1956          1720.00
# 1957          1805.00
# 1958          1775.00
# 1959          1710.00
# 1960          1825.00
# 1961          1806.00
# 1962          1845.00
# 1963          1935.00
# 1964          1975.00
# 1965          2030.00
# 1966          1860.00
# 1967          1780.00
# 1968          1800.00
# 1969          1620.00
# 1970          1720.00
# 1971          1615.00
# 1972          1800.00
# 1973          2050.00
# 1974          1960.00
# 1975          2030.00
# 1976          2080.00
# 1977          2070.00
# 1978          2140.00
# 1979          2110.00
# 1980          1945.00
# 1981          1780.00
# 1982          2010.00
# 1983          1830.00
# 1984          2060.00
# 1985          1915.00
# 1986          2010.00
# 1987          2090.00
# 1988          2220.00
# 1989          2275.00
# 1990          2395.00
# 1991          2415.00
# 1992          2250.00
# 1993          2345.00
# 1994          2040.00
# 1995          2270.00
# 1996          2280.00
# 1997          2360.00
# 1998          2460.00
# 1999          2400.00
# 2000          2485.00
# 2001          2680.00
# 2002          2420.00
# 2003          2330.00
# 2004          2400.00
# 2005          2258.50
# 2006          2445.00
# 2007          1980.00
# 2008          1780.00
# 2009          1722.00
# 2010          2080.00
# 2011          2270.00
# 2012          2237.50
# 2013          2580.00
# 2014          2650.00
# 2015          2590.00

# %% [markdown]
# ## What is the standard deviation of the room size of the property per year of construction?

# %%
data[['sqft_living', 'yr_built']].groupby('yr_built').std().reset_index()
# Out:
#      yr_built  sqft_living
# 0        1900       732.94
# 1        1901       668.23
# 2        1902       878.66
# 3        1903       469.72
# 4        1904      1076.87
# 5        1905       890.84
# 6        1906       961.13
# 7        1907       946.17
# 8        1908       696.23
# 9        1909       935.36
# 10       1910      1280.78
# 11       1911       767.53
# 12       1912       826.99
# 13       1913       727.76
# 14       1914       787.29
# 15       1915       761.57
# 16       1916       926.83
# 17       1917       657.68
# 18       1918       822.47
# 19       1919       693.38
# 20       1920       607.51
# 21       1921       752.80
# 22       1922       908.30
# 23       1923       812.13
# 24       1924       747.94
# 25       1925       748.50
# 26       1926       711.47
# 27       1927       810.02
# 28       1928       781.68
# 29       1929       645.68
# 30       1930       778.05
# 31       1931       845.29
# 32       1932       643.26
# 33       1933      1448.27
# 34       1934       811.12
# 35       1935      1091.48
# 36       1936      1009.89
# 37       1937       882.89
# 38       1938       925.67
# 39       1939       783.99
# 40       1940       994.16
# 41       1941       788.48
# 42       1942       553.00
# 43       1943       564.83
# 44       1944       490.72
# 45       1945       571.10
# 46       1946       679.40
# 47       1947       735.94
# 48       1948       703.15
# 49       1949       740.57
# 50       1950       782.27
# 51       1951       774.25
# 52       1952       783.72
# 53       1953       829.35
# 54       1954       633.41
# 55       1955       658.40
# 56       1956       581.55
# 57       1957       661.65
# 58       1958       732.50
# 59       1959       673.79
# 60       1960       703.99
# 61       1961       613.96
# 62       1962       645.55
# 63       1963       682.98
# 64       1964       760.89
# 65       1965       893.81
# 66       1966       686.10
# 67       1967       715.43
# 68       1968       729.34
# 69       1969       793.66
# 70       1970       843.30
# 71       1971       822.43
# 72       1972       843.00
# 73       1973       768.81
# 74       1974       603.26
# 75       1975       697.85
# 76       1976       752.85
# 77       1977       677.28
# 78       1978       748.48
# 79       1979       694.91
# 80       1980       819.52
# 81       1981       730.12
# 82       1982       899.47
# 83       1983       918.70
# 84       1984       887.12
# 85       1985       775.08
# 86       1986       764.15
# 87       1987       752.41
# 88       1988       894.53
# 89       1989       843.64
# 90       1990       896.96
# 91       1991      1080.97
# 92       1992       861.88
# 93       1993       872.31
# 94       1994       754.33
# 95       1995       843.19
# 96       1996      1133.24
# 97       1997       832.38
# 98       1998       933.00
# 99       1999      1201.43
# 100      2000      1099.70
# 101      2001      1242.67
# 102      2002      1021.41
# 103      2003       937.99
# 104      2004      1057.25
# 105      2005      1029.71
# 106      2006      1117.60
# 107      2007      1150.27
# 108      2008      1143.12
# 109      2009       889.15
# 110      2010       859.26
# 111      2011       804.86
# 112      2012       771.43
# 113      2013       883.50
# 114      2014       893.81
# 115      2015      1155.61

# %% [markdown]
# ## How is the average growth in the purchase price of real estate, per year, per day and per week of the year

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = data['date'].dt.year
data['week_of_year'] = data['date'].dt.strftime('%Y-%W')

aux = data[['price', 'date']].groupby('date').mean().reset_index()
plt.subplot(3,1,1)
sns.lineplot(x='date', y='price', data=aux);

aux1 = data[['price', 'year']].groupby('year').mean().reset_index()
plt.subplot(3,1,2)
sns.lineplot(x='year', y='price', data=aux1);

aux2 = data[['price', 'week_of_year']].groupby('week_of_year').mean().reset_index()
plt.subplot(3,1,3)
sns.lineplot(x='week_of_year', y='price', data=aux2);
plt.xticks(rotation=60);

# %% [markdown]
# ## Look at the map and be able to identify the houses with the highest price

# %%
df = data[['id', 'price', 'lat', 'long']]
mapa = px.scatter_mapbox(df, lat="lat", lon="long", hover_name='id', hover_data=['price'], size='price', size_max=15, zoom=10)

mapa.update_layout(mapbox_style='open-street-map')
mapa.update_layout( height=600, margin={'r':0, 't':0, 'l':0, 'b':0})

mapa.show()

# %% [markdown]
# ## Create a new column called 'dormitory_type'

# %%
data['dormitory_type'] = data['bedrooms'].apply(lambda x: 'studio' if x == 1 else 'apartament' if x == 2 else 'house')

# %% [markdown]
# ## Make a bar graph that represents the mean of the prices by the number of rooms

# %%
aux = data[['price', 'bedrooms']].groupby( 'bedrooms' ).mean().reset_index()
sns.barplot(x='bedrooms', y='price', data=aux);

# %% [markdown]
# ## Make a line graph that represents the average prices for the year of construction of the properties.

# %%
aux = data[['yr_built', 'price']].groupby('yr_built').mean().reset_index()
sns.lineplot(x='yr_built', y='price', data=aux);

# %% [markdown]
# ## Make a bar graph that represents the average price by type of dorms.

# %%
aux = data[['dormitory_type', 'price']].groupby('dormitory_type').mean().reset_index()
sns.barplot(x='dormitory_type', y='price', data=aux);

# %% [markdown]
# ## Draw a line graph that shows the evolution of the average prices for the year of renovation of the buildings, starting in the year 1930

# %%
data['yr_renovated'] = data['yr_renovated'].apply(lambda x: pd.to_datetime('1900-01-01') if x == 0 else pd.to_datetime(x, format='%Y'))

aux = data[['yr_renovated', 'price']].groupby('yr_renovated').mean().reset_index()
aux = aux[aux['yr_renovated'] > '1930-01-01']
sns.lineplot(x='yr_renovated', y='price', data=aux);

# %% [markdown]
# ## Make a table showing the average prices by year of construction and type of bedroom for the properties

# %%
data[['yr_built', 'dormitory_type', 'price']].groupby(['yr_built', 'dormitory_type']).mean().reset_index()
# Out:
#      yr_built dormitory_type     price
# 0        1900     apartament 589533.33
# 1        1900          house 584854.27
# 2        1900         studio 398944.00
# 3        1901     apartament 452856.40
# 4        1901          house 578619.17
# 5        1902     apartament 511850.00
# 6        1902          house 709634.09
# 7        1903     apartament 455959.20
# 8        1903          house 496985.29
# 9        1903         studio 170000.00
# 10       1904     apartament 450085.83
# 11       1904          house 672870.52
# 12       1905     apartament 470928.57
# 13       1905          house 842673.18
# 14       1905         studio 365000.00
# 15       1906     apartament 451517.08
# 16       1906          house 768908.36
# 17       1906         studio 393750.00
# 18       1907     apartament 461496.15
# 19       1907          house 755046.35
# 20       1907         studio 320000.00
# 21       1908     apartament 449093.95
# 22       1908          house 616400.23
# 23       1908         studio 375650.00
# 24       1909     apartament 456548.54
# 25       1909          house 787741.81
# 26       1910     apartament 457297.14
# 27       1910          house 777163.36
# 28       1910         studio 407325.00
# 29       1911     apartament 406766.67
# 30       1911          house 699393.86
# 31       1911         studio 356250.00
# 32       1912     apartament 436658.16
# 33       1912          house 678809.49
# 34       1912         studio  80000.00
# 35       1913     apartament 371405.56
# 36       1913          house 624253.20
# 37       1914     apartament 476289.88
# 38       1914          house 686693.24
# 39       1914         studio 190000.00
# 40       1915     apartament 394845.17
# 41       1915          house 683596.59
# 42       1915         studio 123950.00
# 43       1916     apartament 440620.83
# 44       1916          house 689228.62
# 45       1916         studio 352500.00
# 46       1917     apartament 353050.00
# 47       1917          house 603396.25
# 48       1917         studio 142500.00
# 49       1918     apartament 360088.46
# 50       1918          house 582014.24
# 51       1918         studio 346794.44
# 52       1919     apartament 404010.52
# 53       1919          house 615636.84
# 54       1919         studio 258500.00
# 55       1920     apartament 383228.85
# 56       1920          house 540232.52
# 57       1920         studio 285750.00
# 58       1921     apartament 422495.65
# 59       1921          house 698483.46
# 60       1921         studio 565000.00
# 61       1922     apartament 378857.14
# 62       1922          house 677924.90
# 63       1922         studio 296220.00
# 64       1923     apartament 429254.47
# 65       1923          house 774303.51
# 66       1923         studio 321666.67
# 67       1924     apartament 461053.15
# 68       1924          house 655506.25
# 69       1924         studio 389400.00
# 70       1925     apartament 431448.84
# 71       1925          house 670156.20
# 72       1925         studio 550000.00
# 73       1926     apartament 432173.26
# 74       1926          house 697159.39
# 75       1926         studio 184666.67
# 76       1927     apartament 492102.27
# 77       1927          house 701941.49
# 78       1927         studio 400000.00
# 79       1928     apartament 414245.65
# 80       1928          house 684073.69
# 81       1928         studio 271250.00
# 82       1929     apartament 435483.50
# 83       1929          house 602721.44
# 84       1929         studio 377000.00
# 85       1930     apartament 327729.41
# 86       1930          house 675958.28
# 87       1930         studio 237450.00
# 88       1931     apartament 479936.36
# 89       1931          house 710803.06
# 90       1931         studio 250000.00
# 91       1932     apartament 307166.67
# 92       1932          house 557046.09
# 93       1933     apartament 296714.29
# 94       1933          house 916717.39
# 95       1934     apartament 387650.00
# 96       1934          house 557121.88
# 97       1935     apartament 345141.43
# 98       1935          house 697716.07
# 99       1935         studio 276000.00
# 100      1936     apartament 476729.17
# 101      1936          house 743836.54
# 102      1936         studio 312450.00
# 103      1937     apartament 401210.53
# 104      1937          house 774847.17
# 105      1937         studio 278258.33
# 106      1938     apartament 375148.43
# 107      1938          house 666416.06
# 108      1939     apartament 409534.72
# 109      1939          house 711544.32
# 110      1939         studio 218620.00
# 111      1940     apartament 391751.64
# 112      1940          house 658572.38
# 113      1940         studio 373333.33
# 114      1941     apartament 381381.59
# 115      1941          house 632573.62
# 116      1941         studio 221000.00
# 117      1942     apartament 351052.26
# 118      1942          house 411430.42
# 119      1942         studio 221780.00
# 120      1943     apartament 300892.74
# 121      1943          house 359508.14
# 122      1943         studio 430000.00
# 123      1944     apartament 317597.71
# 124      1944          house 376058.18
# 125      1944         studio 254000.00
# 126      1945     apartament 347178.26
# 127      1945          house 492767.01
# 128      1945         studio 301860.00
# 129      1946     apartament 420936.28
# 130      1946          house 581345.79
# 131      1946         studio 399225.00
# 132      1947     apartament 367468.30
# 133      1947          house 512565.11
# 134      1947         studio 233600.00
# 135      1948     apartament 340158.18
# 136      1948          house 485695.65
# 137      1948         studio 295900.00
# 138      1949     apartament 343238.46
# 139      1949          house 573195.30
# 140      1949         studio 244262.50
# 141      1950     apartament 374424.10
# 142      1950          house 541656.42
# 143      1950         studio 392290.00
# 144      1951     apartament 367087.92
# 145      1951          house 635170.89
# 146      1952     apartament 396502.71
# 147      1952          house 569427.58
# 148      1952         studio 291970.00
# 149      1953     apartament 364822.42
# 150      1953          house 519620.56
# 151      1953         studio 360000.00
# 152      1954     apartament 374541.77
# 153      1954          house 466035.81
# 154      1954         studio 398666.67
# 155      1955     apartament 350416.35
# 156      1955          house 461370.03
# 157      1956     apartament 383823.68
# 158      1956          house 479472.27
# 159      1957     apartament 398790.67
# 160      1957          house 491763.46
# 161      1958     apartament 265930.00
# 162      1958          house 488516.58
# 163      1958         studio 598800.00
# 164      1959     apartament 410787.50
# 165      1959          house 450638.66
# 166      1960     apartament 332250.00
# 167      1960          house 461224.20
# 168      1960         studio 400000.00
# 169      1961     apartament 323330.00
# 170      1961          house 437734.40
# 171      1961         studio 345000.00
# 172      1962     apartament 373037.50
# 173      1962          house 440710.56
# 174      1962         studio 205666.67
# 175      1963     apartament 478388.89
# 176      1963          house 495711.62
# 177      1963         studio 322735.33
# 178      1964     apartament 385800.00
# 179      1964          house 518087.06
# 180      1965     apartament 361062.50
# 181      1965          house 502568.02
# 182      1966     apartament 404333.33
# 183      1966          house 448758.08
# 184      1966         studio  75000.00
# 185      1967     apartament 278140.00
# 186      1967          house 445449.30
# 187      1967         studio 558333.33
# 188      1968     apartament 339269.25
# 189      1968          house 462315.36
# 190      1968         studio 283700.00
# 191      1969     apartament 273986.36
# 192      1969          house 431600.58
# 193      1970     apartament 480990.00
# 194      1970          house 438161.59
# 195      1971     apartament 430000.00
# 196      1971          house 442111.33
# 197      1972     apartament 320190.00
# 198      1972          house 543434.78
# 199      1973     apartament 304400.00
# 200      1973          house 548002.68
# 201      1974     apartament 419444.44
# 202      1974          house 508842.40
# 203      1975     apartament 309620.00
# 204      1975          house 518272.74
# 205      1976     apartament 403638.33
# 206      1976          house 534192.46
# 207      1976         studio 316500.00
# 208      1977     apartament 339562.50
# 209      1977          house 498380.38
# 210      1977         studio 550000.00
# 211      1978     apartament 310205.88
# 212      1978          house 481435.56
# 213      1978         studio 169000.00
# 214      1979     apartament 388912.50
# 215      1979          house 490866.16
# 216      1979         studio 343000.00
# 217      1980     apartament 304752.38
# 218      1980          house 509651.74
# 219      1981     apartament 348546.56
# 220      1981          house 483385.85
# 221      1982     apartament 275035.00
# 222      1982          house 595339.26
# 223      1982         studio 285000.00
# 224      1983     apartament 336635.71
# 225      1983          house 524724.61
# 226      1983         studio 380000.00
# 227      1984     apartament 343623.15
# 228      1984          house 568490.96
# 229      1985     apartament 552935.35
# 230      1985          house 508453.57
# 231      1986     apartament 310068.58
# 232      1986          house 486818.61
# 233      1987     apartament 414245.33
# 234      1987          house 521950.07
# 235      1988     apartament 580166.67
# 236      1988          house 585533.11
# 237      1988         studio 166000.00
# 238      1989     apartament 814812.50
# 239      1989          house 581167.15
# 240      1989         studio 167000.00
# 241      1990     apartament 475203.57
# 242      1990          house 568027.04
# 243      1991     apartament 641166.67
# 244      1991          house 631796.15
# 245      1991         studio 272000.00
# 246      1992     apartament 465400.00
# 247      1992          house 550313.59
# 248      1993     apartament 376580.00
# 249      1993          house 561181.28
# 250      1994     apartament 502500.00
# 251      1994          house 486512.48
# 252      1995     apartament 275833.33
# 253      1995          house 588885.31
# 254      1996     apartament 279416.67
# 255      1996          house 652516.99
# 256      1996         studio 506000.00
# 257      1997     apartament 491435.71
# 258      1997          house 610777.81
# 259      1998     apartament 422541.67
# 260      1998          house 598578.13
# 261      1999     apartament 354990.28
# 262      1999          house 661624.13
# 263      1999         studio 527550.00
# 264      2000     apartament 532339.29
# 265      2000          house 695674.70
# 266      2000         studio 325500.00
# 267      2001     apartament 599550.00
# 268      2001          house 751954.19
# 269      2001         studio 316000.00
# 270      2002     apartament 519522.22
# 271      2002          house 581136.63
# 272      2003     apartament 419767.31
# 273      2003          house 567815.72
# 274      2004     apartament 430304.52
# 275      2004          house 618613.18
# 276      2005     apartament 425879.21
# 277      2005          house 610322.16
# 278      2006     apartament 457948.89
# 279      2006          house 665950.76
# 280      2006         studio 344000.00
# 281      2007     apartament 463989.44
# 282      2007          house 656898.58
# 283      2007         studio 253083.33
# 284      2008     apartament 411294.40
# 285      2008          house 698690.12
# 286      2008         studio 337250.00
# 287      2009     apartament 469262.22
# 288      2009          house 532021.87
# 289      2009         studio 382500.00
# 290      2010     apartament 500988.46
# 291      2010          house 556692.68
# 292      2011     apartament 542488.18
# 293      2011          house 546699.07
# 294      2011         studio 310000.00
# 295      2012     apartament 477755.77
# 296      2012          house 531561.92
# 297      2013     apartament 429441.43
# 298      2013          house 687533.74
# 299      2014     apartament 519182.54
# 300      2014          house 692687.72
# 301      2014         studio 516500.00
# 302      2015     apartament 543250.00
# 303      2015          house 797383.06
# 304      2015         studio 385195.00

# %% [markdown]
# ## Create a Dashboard with the graphs of questions 02,03,04 (1 row and 2 columns)

# %%
from matplotlib import gridspec
from matplotlib import pyplot as plt

fig = plt.figure( figsize=(24,12))
spec = gridspec.GridSpec( ncols=2 , nrows=2 ,figure=fig)

ax1 = fig.add_subplot( spec[0, :] ) #primeira linha e as 2 colunas
ax2 = fig.add_subplot( spec[1, 0] ) #segunda linha e a primeira coluna
ax3 = fig.add_subplot( spec[1, 1] ) #segunda linha e a segunda coluna


aux = data[['price', 'bedrooms']].groupby( 'bedrooms' ).mean().reset_index()
ax1.bar(aux['bedrooms'], aux['price']);

aux = data[['dormitory_type', 'price']].groupby('dormitory_type').mean().reset_index()
ax2.bar(aux['dormitory_type'], aux['price']);


aux = data[['yr_built', 'price']].groupby('yr_built').mean().reset_index()
ax3.plot(aux['yr_built'], aux['price']);

# %% [markdown]
# ## Create a Dashboard with the graphs of questions 02 and 04 (2 columns)

# %%
aux = data[['yr_built', 'price']].groupby('yr_built').mean().reset_index()
plt.subplot(1, 2, 1);
sns.lineplot(x='yr_built', y='price', data=aux);


data['yr_renovated'] = data['yr_renovated'].apply(lambda x: pd.to_datetime('1900-01-01') if x == 0 else pd.to_datetime(x, format='%Y'))

aux = data[['yr_renovated', 'price']].groupby('yr_renovated').mean().reset_index()
aux = aux[aux['yr_renovated'] > '1930-01-01']
plt.subplot(1, 2, 2);
sns.lineplot(x='yr_renovated', y='price', data=aux);
